# %%
# !pip install orange3
# Out:
# Collecting orange3
#   Downloading Orange3-3.37.0-cp311-cp311-win_amd64.whl.metadata (3.7 kB)
# Collecting AnyQt>=0.2.0 (from orange3)
#   Downloading AnyQt-0.2.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting baycomp>=1.0.2 (from orange3)
#   Downloading baycomp-1.0.3.tar.gz (15 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting bottleneck>=1.3.4 (from orange3)
#   Downloading Bottleneck-1.4.2-cp311-cp311-win_amd64.whl.metadata (7.9 kB)
# Collecting catboost>=1.0.1 (from orange3)
#   Downloading catboost-1.2.7-cp311-cp311-win_amd64.whl.metadata (1.2 kB)
# Collecting chardet>=3.0.2 (from orange3)
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: httpx>=0.21.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from orange3) (0.27.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from orange3) (1.3.2)
# Collecting keyring (from orange3)
#   Downloading keyring-25.5.0-py3-none-any.whl.metadata (20 kB)
# Collecting keyrings.alt (from orange3)
#   Downloading keyrings.alt-5.0.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from orange3) (3.8.0)
# Requirement already satisfied: networkx in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from orange3) (3.3)
# Requirement already satisfied: numpy<2,>=1.20.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from orange3) (1.26.1)
# Collecting openTSNE!=0.7.0,>=0.6.1 (from orange3)
#   Downloading openTSNE-1.0.2-cp311-cp311-win_amd64.whl.metadata (8.0 kB)
# Requirement already satisfied: openpyxl in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from orange3) (3.1.5)
# Collecting orange-canvas-core<0.3a,>=0.2a (from orange3)
#   Downloading orange_canvas_core-0.2.4-py3-none-any.whl.metadata (2.1 kB)
# Collecting orange-widget-base>=4.23.0 (from orange3)
#   Downloading orange_widget_base-4.25.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: packaging in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from orange3) (23.2)
# Requirement already satisfied: pandas!=1.5.0,!=2.0.0,>=1.4.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from orange3) (2.1.2)
# Requirement already satisfied: pip>=19.3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from orange3) (24.3.1)
# Requirement already satisfied: pygments>=2.8.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from orange3) (2.17.2)
# Collecting pyqtgraph>=0.13.1 (from orange3)
#   Downloading pyqtgraph-0.13.7-py3-none-any.whl.metadata (1.3 kB)
# Collecting python-louvain>=0.13 (from orange3)
#   Downloading python-louvain-0.16.tar.gz (204 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pyyaml in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from orange3) (6.0.1)
# Requirement already satisfied: qtconsole>=4.7.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from orange3) (5.5.1)
# Requirement already satisfied: requests in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from orange3) (2.31.0)
# Requirement already satisfied: scikit-learn<1.5.0,>=1.3.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from orange3) (1.4.0)
# Requirement already satisfied: scipy>=1.9 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from orange3) (1.11.4)
# Collecting serverfiles (from orange3)
#   Downloading serverfiles-0.3.1.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: xgboost>=1.7.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from orange3) (2.1.1)
# Requirement already satisfied: xlrd>=1.2.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from orange3) (2.0.1)
# Collecting xlsxwriter (from orange3)
#   Downloading XlsxWriter-3.2.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: graphviz in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from catboost>=1.0.1->orange3) (0.20.3)
# Requirement already satisfied: plotly in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from catboost>=1.0.1->orange3) (5.23.0)
# Requirement already satisfied: six in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from catboost>=1.0.1->orange3) (1.16.0)
# Requirement already satisfied: anyio in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.21.0->orange3) (4.2.0)
# Requirement already satisfied: certifi in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.21.0->orange3) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.21.0->orange3) (1.0.5)
# Requirement already satisfied: idna in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.21.0->orange3) (3.6)
# Requirement already satisfied: sniffio in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.21.0->orange3) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx>=0.21.0->orange3) (0.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.2.0->orange3) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.2.0->orange3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.2.0->orange3) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.2.0->orange3) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.2.0->orange3) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.2.0->orange3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.2.0->orange3) (2.8.2)
# Collecting docutils (from orange-canvas-core<0.3a,>=0.2a->orange3)
#   Downloading docutils-0.21.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting commonmark>=0.8.1 (from orange-canvas-core<0.3a,>=0.2a->orange3)
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting requests-cache (from orange-canvas-core<0.3a,>=0.2a->orange3)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting dictdiffer (from orange-canvas-core<0.3a,>=0.2a->orange3)
#   Downloading dictdiffer-0.9.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting qasync>=0.10.0 (from orange-canvas-core<0.3a,>=0.2a->orange3)
#   Downloading qasync-0.27.1-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: typing-extensions in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from orange-canvas-core<0.3a,>=0.2a->orange3) (4.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pandas!=1.5.0,!=2.0.0,>=1.4.0->orange3) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pandas!=1.5.0,!=2.0.0,>=1.4.0->orange3) (2023.3)
# Requirement already satisfied: traitlets!=5.2.1,!=5.2.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from qtconsole>=4.7.2->orange3) (5.14.1)
# Requirement already satisfied: jupyter-core in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from qtconsole>=4.7.2->orange3) (5.7.1)
# Requirement already satisfied: jupyter-client>=4.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from qtconsole>=4.7.2->orange3) (8.6.0)
# Requirement already satisfied: ipykernel>=4.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from qtconsole>=4.7.2->orange3) (6.28.0)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from qtconsole>=4.7.2->orange3) (2.4.1)
# Requirement already satisfied: pyzmq>=17.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from qtconsole>=4.7.2->orange3) (25.1.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn<1.5.0,>=1.3.0->orange3) (3.2.0)
# Collecting jaraco.classes (from keyring->orange3)
#   Downloading jaraco.classes-3.4.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting jaraco.functools (from keyring->orange3)
#   Downloading jaraco.functools-4.1.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting jaraco.context (from keyring->orange3)
#   Downloading jaraco.context-6.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: importlib-metadata>=4.11.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from keyring->orange3) (8.4.0)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from keyring->orange3) (0.2.2)
# Requirement already satisfied: et-xmlfile in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from openpyxl->orange3) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests->orange3) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests->orange3) (1.26.20)
# Requirement already satisfied: zipp>=0.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from importlib-metadata>=4.11.4->keyring->orange3) (3.20.2)
# Requirement already satisfied: comm>=0.1.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipykernel>=4.1->qtconsole>=4.7.2->orange3) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipykernel>=4.1->qtconsole>=4.7.2->orange3) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipykernel>=4.1->qtconsole>=4.7.2->orange3) (8.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipykernel>=4.1->qtconsole>=4.7.2->orange3) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipykernel>=4.1->qtconsole>=4.7.2->orange3) (1.6.0)
# Requirement already satisfied: psutil in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipykernel>=4.1->qtconsole>=4.7.2->orange3) (5.9.8)
# Requirement already satisfied: tornado>=6.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipykernel>=4.1->qtconsole>=4.7.2->orange3) (6.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyter-core->qtconsole>=4.7.2->orange3) (4.1.0)
# Requirement already satisfied: pywin32>=300 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jupyter-core->qtconsole>=4.7.2->orange3) (306)
# Collecting more-itertools (from jaraco.classes->keyring->orange3)
#   Downloading more_itertools-10.5.0-py3-none-any.whl.metadata (36 kB)
# Collecting backports.tarfile (from jaraco.context->keyring->orange3)
#   Downloading backports.tarfile-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from plotly->catboost>=1.0.1->orange3) (8.3.0)
# Requirement already satisfied: attrs>=21.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests-cache->orange-canvas-core<0.3a,>=0.2a->orange3) (23.2.0)
# Collecting cattrs>=22.2 (from requests-cache->orange-canvas-core<0.3a,>=0.2a->orange3)
#   Downloading cattrs-24.1.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting url-normalize>=1.4 (from requests-cache->orange-canvas-core<0.3a,>=0.2a->orange3)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: decorator in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->orange3) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->orange3) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->orange3) (3.0.43)
# Requirement already satisfied: stack-data in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->orange3) (0.6.3)
# Requirement already satisfied: colorama in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->orange3) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->orange3) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->orange3) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->orange3) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->orange3) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->orange3) (0.2.2)
# Downloading Orange3-3.37.0-cp311-cp311-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ------------ --------------------------- 1.0/3.5 MB 6.3 MB/s eta 0:00:01
#    --------------- ------------------------ 1.3/3.5 MB 2.7 MB/s eta 0:00:01
#    ------------------------ --------------- 2.1/3.5 MB 3.8 MB/s eta 0:00:01
#    --------------------------------- ------ 2.9/3.5 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 3.2 MB/s eta 0:00:00
# Downloading AnyQt-0.2.0-py3-none-any.whl (56 kB)
# Downloading Bottleneck-1.4.2-cp311-cp311-win_amd64.whl (111 kB)
# Downloading catboost-1.2.7-cp311-cp311-win_amd64.whl (101.7 MB)
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#     --------------------------------------- 1.3/101.7 MB 6.7 MB/s eta 0:00:16
#    - -------------------------------------- 3.1/101.7 MB 8.0 MB/s eta 0:00:13
#    - -------------------------------------- 4.7/101.7 MB 7.7 MB/s eta 0:00:13
#    -- ------------------------------------- 7.1/101.7 MB 8.7 MB/s eta 0:00:11
#    --- ------------------------------------ 9.4/101.7 MB 9.2 MB/s eta 0:00:11
#    ---- ----------------------------------- 10.7/101.7 MB 9.2 MB/s eta 0:00:10
#    ---- ----------------------------------- 12.3/101.7 MB 8.7 MB/s eta 0:00:11
#    ----- ---------------------------------- 14.4/101.7 MB 8.7 MB/s eta 0:00:11
#    ------ --------------------------------- 16.0/101.7 MB 8.7 MB/s eta 0:00:10
#    ------- -------------------------------- 18.4/101.7 MB 8.8 MB/s eta 0:00:10
#    -------- ------------------------------- 20.4/101.7 MB 9.0 MB/s eta 0:00:10
#    -------- ------------------------------- 22.8/101.7 MB 9.1 MB/s eta 0:00:09
#    --------- ------------------------------ 24.6/101.7 MB 9.1 MB/s eta 0:00:09
#    ---------- ----------------------------- 26.2/101.7 MB 9.0 MB/s eta 0:00:09
#    ----------- ---------------------------- 28.0/101.7 MB 9.0 MB/s eta 0:00:09
#    ----------- ---------------------------- 30.1/101.7 MB 9.0 MB/s eta 0:00:08
#    ------------ --------------------------- 32.2/101.7 MB 9.2 MB/s eta 0:00:08
#    ------------- -------------------------- 34.3/101.7 MB 9.1 MB/s eta 0:00:08
#    -------------- ------------------------- 36.2/101.7 MB 9.1 MB/s eta 0:00:08
#    -------------- ------------------------- 38.0/101.7 MB 9.1 MB/s eta 0:00:08
#    --------------- ------------------------ 40.4/101.7 MB 9.2 MB/s eta 0:00:07
#    ---------------- ----------------------- 42.2/101.7 MB 9.2 MB/s eta 0:00:07
#    ----------------- ---------------------- 44.0/101.7 MB 9.2 MB/s eta 0:00:07
#    ------------------ --------------------- 45.9/101.7 MB 9.1 MB/s eta 0:00:07
#    ------------------ --------------------- 46.9/101.7 MB 9.0 MB/s eta 0:00:07
#    ------------------ --------------------- 48.0/101.7 MB 8.8 MB/s eta 0:00:07
#    ------------------- -------------------- 49.0/101.7 MB 8.6 MB/s eta 0:00:07
#    ------------------- -------------------- 49.3/101.7 MB 8.6 MB/s eta 0:00:07
#    ------------------- -------------------- 50.6/101.7 MB 8.3 MB/s eta 0:00:07
#    -------------------- ------------------- 51.6/101.7 MB 8.2 MB/s eta 0:00:07
#    -------------------- ------------------- 52.4/101.7 MB 8.0 MB/s eta 0:00:07
#    --------------------- ------------------ 53.7/101.7 MB 8.0 MB/s eta 0:00:07
#    --------------------- ------------------ 53.7/101.7 MB 8.0 MB/s eta 0:00:07
#    --------------------- ------------------ 53.7/101.7 MB 8.0 MB/s eta 0:00:07
#    --------------------- ------------------ 54.3/101.7 MB 7.4 MB/s eta 0:00:07
#    --------------------- ------------------ 55.1/101.7 MB 7.2 MB/s eta 0:00:07
#    --------------------- ------------------ 55.8/101.7 MB 7.1 MB/s eta 0:00:07
#    ---------------------- ----------------- 56.6/101.7 MB 7.1 MB/s eta 0:00:07
#    ---------------------- ----------------- 57.7/101.7 MB 7.0 MB/s eta 0:00:07
#    ----------------------- ---------------- 58.7/101.7 MB 7.0 MB/s eta 0:00:07
#    ----------------------- ---------------- 60.0/101.7 MB 6.9 MB/s eta 0:00:07
#    ------------------------ --------------- 61.3/101.7 MB 6.9 MB/s eta 0:00:06
#    ------------------------ --------------- 62.4/101.7 MB 6.8 MB/s eta 0:00:06
#    ------------------------ --------------- 62.7/101.7 MB 6.8 MB/s eta 0:00:06
#    ------------------------- -------------- 63.7/101.7 MB 6.7 MB/s eta 0:00:06
#    ------------------------- -------------- 64.2/101.7 MB 6.6 MB/s eta 0:00:06
#    ------------------------- -------------- 64.7/101.7 MB 6.5 MB/s eta 0:00:06
#    ------------------------- -------------- 65.5/101.7 MB 6.5 MB/s eta 0:00:06
#    -------------------------- ------------- 66.3/101.7 MB 6.4 MB/s eta 0:00:06
#    -------------------------- ------------- 67.1/101.7 MB 6.3 MB/s eta 0:00:06
#    -------------------------- ------------- 67.9/101.7 MB 6.3 MB/s eta 0:00:06
#    -------------------------- ------------- 68.4/101.7 MB 6.2 MB/s eta 0:00:06
#    --------------------------- ------------ 68.9/101.7 MB 6.2 MB/s eta 0:00:06
#    --------------------------- ------------ 70.3/101.7 MB 6.1 MB/s eta 0:00:06
#    ---------------------------- ----------- 71.8/101.7 MB 6.2 MB/s eta 0:00:05
#    ---------------------------- ----------- 72.9/101.7 MB 6.2 MB/s eta 0:00:05
#    ----------------------------- ---------- 74.2/101.7 MB 6.1 MB/s eta 0:00:05
#    ----------------------------- ---------- 75.0/101.7 MB 6.1 MB/s eta 0:00:05
#    ----------------------------- ---------- 76.0/101.7 MB 6.1 MB/s eta 0:00:05
#    ------------------------------ --------- 77.6/101.7 MB 6.1 MB/s eta 0:00:04
#    ------------------------------- -------- 78.9/101.7 MB 6.1 MB/s eta 0:00:04
#    ------------------------------- -------- 80.7/101.7 MB 6.1 MB/s eta 0:00:04
#    -------------------------------- ------- 82.6/101.7 MB 6.2 MB/s eta 0:00:04
#    --------------------------------- ------ 84.7/101.7 MB 6.2 MB/s eta 0:00:03
#    --------------------------------- ------ 85.7/101.7 MB 6.2 MB/s eta 0:00:03
#    ---------------------------------- ----- 87.6/101.7 MB 6.3 MB/s eta 0:00:03
#    ----------------------------------- ---- 89.7/101.7 MB 6.3 MB/s eta 0:00:02
#    ------------------------------------ --- 91.8/101.7 MB 6.4 MB/s eta 0:00:02
#    ------------------------------------ --- 93.8/101.7 MB 6.4 MB/s eta 0:00:02
#    ------------------------------------- -- 95.7/101.7 MB 6.4 MB/s eta 0:00:01
#    -------------------------------------- - 97.5/101.7 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  99.9/101.7 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  101.7/101.7 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 101.7/101.7 MB 6.5 MB/s eta 0:00:00
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
# Downloading openTSNE-1.0.2-cp311-cp311-win_amd64.whl (470 kB)
# Downloading orange_canvas_core-0.2.4-py3-none-any.whl (533 kB)
#    ---------------------------------------- 0.0/533.4 kB ? eta -:--:--
#    ---------------------------------------- 533.4/533.4 kB 4.3 MB/s eta 0:00:00
# Downloading orange_widget_base-4.25.0-py3-none-any.whl (270 kB)
# Downloading pyqtgraph-0.13.7-py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.9 MB ? eta -:--:--
#    -------------------------------- ------- 1.6/1.9 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 5.6 MB/s eta 0:00:00
# Downloading keyring-25.5.0-py3-none-any.whl (39 kB)
# Downloading keyrings.alt-5.0.2-py3-none-any.whl (17 kB)
# Downloading XlsxWriter-3.2.0-py3-none-any.whl (159 kB)
# Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
# Downloading qasync-0.27.1-py3-none-any.whl (14 kB)
# Downloading dictdiffer-0.9.0-py2.py3-none-any.whl (16 kB)
# Downloading docutils-0.21.2-py3-none-any.whl (587 kB)
#    ---------------------------------------- 0.0/587.4 kB ? eta -:--:--
#    ---------------------------------------- 587.4/587.4 kB 5.2 MB/s eta 0:00:00
# Downloading jaraco.classes-3.4.0-py3-none-any.whl (6.8 kB)
# Downloading jaraco.context-6.0.1-py3-none-any.whl (6.8 kB)
# Downloading jaraco.functools-4.1.0-py3-none-any.whl (10 kB)
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
# Downloading cattrs-24.1.2-py3-none-any.whl (66 kB)
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Downloading backports.tarfile-1.2.0-py3-none-any.whl (30 kB)
# Downloading more_itertools-10.5.0-py3-none-any.whl (60 kB)
# Building wheels for collected packages: baycomp, python-louvain, serverfiles
#   Building wheel for baycomp (setup.py): started
#   Building wheel for baycomp (setup.py): finished with status 'done'
#   Created wheel for baycomp: filename=baycomp-1.0.3-py3-none-any.whl size=18057 sha256=7b323aa7da63f08475830bd876d5519348b743ac3d6b2cc5c168a7b820fc6b09
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\2b\a2\b8\9c0b9ffde746a4e0c20639b46eae34dda4e0588efebde8916e
#   Building wheel for python-louvain (setup.py): started
#   Building wheel for python-louvain (setup.py): finished with status 'done'
#   Created wheel for python-louvain: filename=python_louvain-0.16-py3-none-any.whl size=9404 sha256=8b3add39dc335503048ff5570b5cb2bd24bf046271dfc20434ec4974d4fc73d6
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\11\c1\e7\f62a211c636275e2da798bf0c307a3ae79aeddaf2524a03ce4
#   Building wheel for serverfiles (setup.py): started
#   Building wheel for serverfiles (setup.py): finished with status 'done'
#   Created wheel for serverfiles: filename=serverfiles-0.3.1-py3-none-any.whl size=6930 sha256=c60ff580630c2d32c587190b29625c2f2272aa26b9f54789ca4c3c5be6564709
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\10\fe\96\2239afdbcabbbd85b1836ef431e6ce960f1bc84d7ff0520f5b
# Successfully built baycomp python-louvain serverfiles
# Installing collected packages: dictdiffer, commonmark, xlsxwriter, url-normalize, qasync, python-louvain, pyqtgraph, more-itertools, docutils, chardet, cattrs, bottleneck, backports.tarfile, AnyQt, serverfiles, requests-cache, jaraco.functools, jaraco.context, jaraco.classes, orange-canvas-core, openTSNE, keyrings.alt, keyring, catboost, baycomp, orange-widget-base, orange3
# Successfully installed AnyQt-0.2.0 backports.tarfile-1.2.0 baycomp-1.0.3 bottleneck-1.4.2 catboost-1.2.7 cattrs-24.1.2 chardet-5.2.0 commonmark-0.9.1 dictdiffer-0.9.0 docutils-0.21.2 jaraco.classes-3.4.0 jaraco.context-6.0.1 jaraco.functools-4.1.0 keyring-25.5.0 keyrings.alt-5.0.2 more-itertools-10.5.0 openTSNE-1.0.2 orange-canvas-core-0.2.4 orange-widget-base-4.25.0 orange3-3.37.0 pyqtgraph-0.13.7 python-louvain-0.16 qasync-0.27.1 requests-cache-1.2.1 serverfiles-0.3.1 url-normalize-1.4.3 xlsxwriter-3.2.0

# %%
# First install Orange:
# pip install orange3

import Orange
from Orange.data import Table, Domain, ContinuousVariable, DiscreteVariable
from Orange.classification import RandomForestLearner
from Orange.evaluation import CrossValidation, scoring

# Load built-in dataset
iris = Table("iris")

# Create a new dataset from scratch
domain = Domain([
    ContinuousVariable("age"),
    ContinuousVariable("income"),
    DiscreteVariable("education", values=["primary", "secondary", "tertiary"]),
    DiscreteVariable("employed", values=["yes", "no"])
])

# Create sample data
data = Table.from_list(domain, [
    [25, 30000, "secondary", "yes"],
    [45, 60000, "tertiary", "yes"],
    [35, 45000, "secondary", "no"],
])

# Example 1: Basic Classification with Random Forest
# Split data into features and target
features = iris[:, :-1]  # all columns except the last
target = iris[:, -1]     # only the last column

# Train a random forest classifier
rf_learner = RandomForestLearner(n_estimators=100)
rf_classifier = rf_learner(iris)

# Make predictions
predictions = rf_classifier(features)

# Example 2: Cross Validation
# Perform 5-fold cross validation
cv = CrossValidation(n_splits=5)
cv_results = cv(iris, [rf_learner])

# Print accuracy score
print(f"Accuracy: {scoring.CA(cv_results)[0]:.3f}")

# Example 3: Data Preprocessing and Visualization
from Orange.preprocess import Normalize, Discretize
from Orange.widgets.visualize import owscatterplot

# Normalize the data
normalizer = Normalize()
normalized_data = normalizer(iris)

# Discretize a continuous variable
discretizer = Discretize()
discretized_data = discretizer(iris)

# Example 4: Feature Selection
from Orange.preprocess import SelectBestFeatures

# Select top 2 features
selector = SelectBestFeatures(method="relief", k=2)
selected_data = selector(iris)

# Example 5: Clustering
from Orange.clustering import KMeansLearner

# Perform k-means clustering
kmeans = KMeansLearner(n_clusters=3)
clusters = kmeans(iris)

# Get cluster assignments
cluster_assignments = clusters(iris)

# Example 6: Association Rules
from Orange.associate import AssociationRulesSparseInducer

# Find association rules (requires discrete data)
rules_inducer = AssociationRulesSparseInducer(support=0.3)
rules = rules_inducer(discretized_data)

# Print first few rules
for rule in rules[:3]:
    print(f"{rule}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 6
#       4 import Orange
#       5 from Orange.data import Table, Domain, ContinuousVariable, DiscreteVariable
# ----> 6 from Orange.classification import RandomForestLearner
#       7 from Orange.evaluation import CrossValidation, scoring
#       9 # Load built-in dataset
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\Orange\classification\__init__.py:20
#      18 from .outlier_detection import *
#      19 from .rules import *
# ---> 20 from .sgd import *
#      21 from .neural_network import *
#      22 from .calibration import *
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\Orange\classification\sgd.py:5
#       3 from Orange.base import SklLearner
#       4 from Orange.preprocess import Normalize
# ----> 5 from Orange.regression.linear import LinearModel
#       7 __all__ = ["SGDClassificationLearner"]
#      10 class SGDClassificationLearner(SklLearner):
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\Orange\regression\__init__.py:19
#      17 from ..classification.simple_tree import *
#      18 try:
# ---> 19     from .catgb import *
#      20 except ModuleNotFoundError:
#      21     pass
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\Orange\regression\catgb.py:5
#       1 from typing import Tuple
#       3 import numpy as np
# ----> 5 import catboost
#       7 from Orange.base import CatGBBaseLearner
#       8 from Orange.regression import Learner
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\catboost\__init__.py:20
#      17 CatboostError = CatBoostError
#      19 try:
# ---> 20     from .widget import MetricVisualizer, MetricsPlotter, XGBPlottingCallback, lgbm_plotting_callback  # noqa
#      21     __all__.extend(['MetricVisualizer', 'MetricsPlotter', 'XGBPlottingCallback', 'lgbm_plotting_callback'])
#      22 except Exception:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\catboost\widget\__init__.py:3
#       1 from .ipythonwidget import MetricVisualizer  # noqa
#       2 from .metrics_plotter import MetricsPlotter  # noqa
# ----> 3 from .callbacks import XGBPlottingCallback, lgbm_plotting_callback  # noqa
#       6 def _jupyter_labextension_paths():
#       7     return [{
#       8         'src': 'labextension',
#       9         'dest': 'catboost-widget',
#      10     }]
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\catboost\widget\callbacks.py:2
#       1 try:
# ----> 2     from xgboost.callback import TrainingCallback as XGBTrainingCallback
#       3 except Exception:
#       4     class XGBTrainingCallback:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\__init__.py:6
#       1 """XGBoost: eXtreme Gradient Boosting library.
#       2
#       3 Contributors: https://github.com/dmlc/xgboost/blob/master/CONTRIBUTORS.md
#       4 """
# ----> 6 from . import tracker  # noqa
#       7 from . import collective, dask
#       8 from .core import (
#       9     Booster,
#      10     DataIter,
#    (...)
#      15     build_info,
#      16 )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\tracker.py:9
#       6 from enum import IntEnum, unique
#       7 from typing import Dict, Optional, Union
# ----> 9 from .core import _LIB, _check_call, make_jcargs
#      12 def get_family(addr: str) -> int:
#      13     """Get network family from address."""
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:269
#     265     return lib
#     268 # load the XGBoost library globally
# --> 269 _LIB = _load_lib()
#     272 def _check_call(ret: int) -> None:
#     273     """Check the return value of C API call
#     274
#     275     This function will raise exception when error occurs.
#    (...)
#     281         return value from API calls
#     282     """
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:211, in _load_lib()
#     205 try:
#     206     # needed when the lib is linked with non-system-available
#     207     # dependencies
#     208     os.environ["PATH"] = os.pathsep.join(
#     209         pathBackup + [os.path.dirname(lib_path)]
#     210     )
# --> 211     lib = ctypes.cdll.LoadLibrary(lib_path)
#     212     setattr(lib, "path", os.path.normpath(lib_path))
#     213     lib_success = True
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\ctypes\__init__.py:454, in LibraryLoader.LoadLibrary(self, name)
#     453 def LoadLibrary(self, name):
# --> 454     return self._dlltype(name)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\ctypes\__init__.py:376, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     373 self._FuncPtr = _FuncPtr
#     375 if handle is None:
# --> 376     self._handle = _dlopen(self._name, mode)
#     377 else:
#     378     self._handle = handle
#
# KeyboardInterrupt:
